# %%
menu={1:'大麥克69',2:'雙層牛肉吉事堡59',3:'安格斯黑牛堡99',   
      7:'9塊麥克雞塊89',8:'勁辣雞腿堡69',9:'2塊麥脆雞104',
      10:'3塊麥脆雞156',11:'黃金起司豬排堡49',12:'麥香魚49',
      13:'千島黃金蝦堡69',14:'BLT安格斯黑牛堡109',15:'BLT辣脆雞腿堡109',
      16:'BLT嫩煎雞腿堡109',17:'蕈菇安格斯黑牛堡119',18:'凱薩脆雞沙拉99',
      19:'義式烤雞沙拉99',20:'經典套餐50',21:'清爽配餐50',
      22:'酷炫配餐65',23:'勁脆配餐65',24:'搖搖豪麥配餐79'}

foodlist = {1:'大麥克',2:'雙層牛肉吉事堡',3:'安格斯黑牛堡',4:'嫩煎雞腿堡',5:'麥香雞',6:'6塊麥克雞塊',   
        7:'9塊麥克雞塊',8:'勁辣雞腿堡',9:'2塊麥脆雞',10:'3塊麥脆雞',11:'黃金起司豬排堡',12:'麥香魚',
        13:'千島黃金蝦堡',14:'BLT安格斯黑牛堡',15:'BLT辣脆雞腿堡',16:'BLT嫩煎雞腿堡',17:'蕈菇安格斯黑牛堡',
        18:'凱薩脆雞沙拉',19:'義式烤雞沙拉',20:'經典套餐',21:'清爽配餐',22:'酷炫配餐',23:'勁脆配餐',24:'搖搖豪麥配餐'}
pricelist = {'大麥克':69,'雙層牛肉吉事堡':59,'安格斯黑牛堡':99,'嫩煎雞腿堡':79,'麥香雞':49,'6塊麥克雞塊':59,
         '9塊麥克雞塊':89,'勁辣雞腿堡':69,'2塊麥脆雞':104,'3塊麥脆雞':156,'黃金起司豬排堡':49,'麥香魚':49, 
         '千島黃金蝦堡':69,'BLT安格斯黑牛堡':109,'BLT辣脆雞腿堡':109,'BLT嫩煎雞腿堡':109,'蕈菇安格斯黑牛堡':119,
         '凱薩脆雞沙拉':99,'義式烤雞沙拉':99,'經典套餐':50,'清爽配餐':50,'酷炫配餐':65,'勁脆配餐':65,'搖搖豪麥配餐':79}
print(menu)
order=[] 
orderlist=[] 
price=[] 

######點餐迴圈#######
while True:  #持續運作的迴圈
 
    x=input('請輸入要點餐品項，請輸入代碼(輸入完成輸入quit):') 
    if x=='quit': 
        break     
    else:
        if x.isdecimal(): 
            x=int(x)      
            if x<=24 and x>=1:  #判定x是否<24且>1
               order.append(x)  #
            else:print("你點的餐點不存在")
        else:
            print("你他媽在亂搞!!")

######列出使用者點的餐點#####
for key in order :
    item=foodlist[key]   
    orderlist.append(item)  
print(orderlist)        

#####列出使用者點的餐點的價格#####
for key in orderlist :
    item=pricelist[key] 
    price.append(item) 
print(price)           
print(sum(price))
# Out:
# {1: '大麥克69', 2: '雙層牛肉吉事堡59', 3: '安格斯黑牛堡99', 7: '9塊麥克雞塊89', 8: '勁辣雞腿堡69', 9: '2塊麥脆雞104', 10: '3塊麥脆雞156', 11: '黃金起司豬排堡49', 12: '麥香魚49', 13: '千島黃金蝦堡69', 14: 'BLT安格斯黑牛堡109', 15: 'BLT辣脆雞腿堡109', 16: 'BLT嫩煎雞腿堡109', 17: '蕈菇安格斯黑牛堡119', 18: '凱薩脆雞沙拉99', 19: '義式烤雞沙拉99', 20: '經典套餐50', 21: '清爽配餐50', 22: '酷炫配餐65', 23: '勁脆配餐65', 24: '搖搖豪麥配餐79'}
# 請輸入要點餐品項，請輸入代碼(輸入完成輸入quit):3
# 請輸入要點餐品項，請輸入代碼(輸入完成輸入quit):7
# 請輸入要點餐品項，請輸入代碼(輸入完成輸入quit):25
# 你點的餐點不存在
# 請輸入要點餐品項，請輸入代碼(輸入完成輸入quit):quit
# ['安格斯黑牛堡', '9塊麥克雞塊']
# [99, 89]
# 188
