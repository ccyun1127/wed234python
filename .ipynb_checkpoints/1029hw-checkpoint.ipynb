# %%
print("歡迎使用吃飯小助手")
while True:
    x = input("請選擇功能:1.政大選餐廳,2.投票選餐廳,3.個人化選餐廳,4.結束")
    if x == "1":
        #######環境設定########
        import random  #導入random函數
        x = ["吉野家","楊記","juicy bun","shabu 鮮","subway","jasons熟食區","米塔","舒曼","吃的小館","咖哩飯","京城滷味","飽飽食府"]#大門餐廳集合字串
        a = ["楊記","吃的小館","咖哩飯","京城滷味","飽飽食府"]
        b = ["吉野家","shabu 鮮"]
        c = ["juicy bun","subway","jasons熟食區","米塔","舒曼"]
        y = ["東京小城","大汗","滇味","提洛斯","蝴蝶樣","upstairs","urban monster","大呼過癮","羹大王","佳味","金鰭","華越","秀食屋"]#麥側餐廳集合字串
        d = ["大汗","滇味","大呼過癮","羹大王","佳味","華越"]
        e = ["東京小城","蝴蝶樣","金鰭","秀食屋"]
        f = ["提洛斯","upstairs","urban monster",]
        z = ["麥當勞","摩斯","八方","四川飯館","鬼匠","丐幫滷味","敏忠","樂山","里克","京華小館","甘泉魚麵","四五大街","多果","my麵屋","菁英自助餐"]#商側餐廳集合字串
        g = ["八方","四川飯館","丐幫滷味","敏忠","京華小館","甘泉魚麵","四五大街","多果","my麵屋","菁英自助餐"]
        h = ["摩斯","鬼匠","樂山","多果"]
        i = ["多果",]
        #######隨機出餐廳結果########
        print("歡迎使用政大選餐廳功能")
        while True:
            while True:    
                w = input("要吃甚麼?請輸入地點代碼(大門=1/商側=2/麥側=3)")#讓使用者可以輸入希望餐廳所在的位置
                if w != "1" and w!= "2" and w!="3":
                    print("請輸入正確代碼")
                else:
                    break
            w = int(w)#將輸入的值轉為整數
            if w == 1:
                while True:
                    j=input("要吃甚麼?請輸入種類(中式=1/日式=2/西式=3)")
                    j = int(j)
                    if j==1:
                        print(random.choice(a))
                        break
                    elif j==2:
                        print(random.choice(b))
                        break
                    elif j==3:
                        print(random.choice(c))
                        break
                    else:
                        print("請輸入正確代碼!")
            elif w == 2:
                while True: 
                    k=input("要吃甚麼?請輸入種類(中式=1/日式=2/西式=3)")
                    k = int(k)
                    if k==1:
                        print(random.choice(d))
                        break
                    elif k==2:
                        print(random.choice(e))
                        break
                    elif k==3:
                        print(random.choice(f))
                        break
                    else:
                        print("請輸入正確代碼!")
            elif w== 3:
                 while True:
                    l=input("要吃甚麼?請輸入種類(中式=1/日式=2/西式=3)")
                    l = int(l)
                    if l==1:
                        print(random.choice(g))
                        break
                    elif l==2:
                        print(random.choice(h))
                        break
                    elif l==3:
                        print(random.choice(i ))
                        break
                    else:
                        print("請輸入正確代碼!!")
                        
            m=input("請問您是否滿意此結果?(滿意=1/不滿意=2)")
            if m=="1":
                break
            else:
                continue

    elif x == "2":
        R1 = {"A":"涮乃葉","B":"潮肉","C":"momo paradise","D":"壽喜燒一丁","E":"鍋爸涮涮鍋","F":"肉多多","G":"馬辣","H":"石二鍋"}
        R2 = {"A":"饗食天堂","B":"漢來海港","C":"寒舍愛美","D":"晶華酒店","E":"饗饗",}
        R3 = {"A":"四川飯館","B":"金色漁屋","C":"紅豆食府","D":"開飯","E":"敘緣小館","F":"KiKi餐廳"}
        R4 = {"A":"非常泰","B":"蘇阿姨","C":"Friday's","D":"兩班家","E":"小曼谷","F":"欣葉","G":"Juicy Bun","H":"起家雞"}
        print("歡迎使用投票選餐廳功能")
        while True:
            x = str(input("(代碼:A,火鍋和壽喜燒,B,Buffet,C,中式合菜,D,異國料理,)\n請輸入你想吃的料理風格:"))       
            if x == "A":
                while True:
                    y=input("請輸入投票人數：")
                    if y.isdecimal()==False:
                        print("輸入錯誤！請重新輸入")
                    else:
                        break
                print("請從下列餐廳中選擇")
                for z in R1:
                    print(z,R1[z],)
                print("現在開始投票")
                count=int(y)
                data = []
                for item in range(count):
                    while True:
                            x = input("第"+str(item+1)+"位投票者請投票:")
                            if x == "A" or x == "B" or x == "C" or x == "D" or x == "E" or x == "F" or x == "G" or x == "H" :
                                data.append(x)
                                break
                            else:
                                print("輸入錯誤！請重新輸入")
                else:print("投票完成")
                from collections import Counter
                word_counts = Counter(data)
                z = word_counts.most_common(1)
                for i, j in z:
                     print("最高票為",R1[i],"得到",j,"票")
                break
            elif x == "B":
                while True:
                    y=input("請輸入投票人數：")
                    if y.isdecimal()==False:
                        print("輸入錯誤！請重新輸入")
                    else:
                        break
                print("請從下列餐廳中選擇")
                for z in R2:
                    print(z,R2[z],)
                print("現在開始投票")
                count = int(y)
                data = []
                for item in range(count):
                    while True:
                            x = input("第"+str(item+1)+"位投票者請投票:")
                            if x == "A" or x == "B" or x == "C" or x == "D" or x == "E": 
                                data.append(x)
                                break
                            else:
                                print("輸入錯誤！請重新輸入")
                else:print("投票完成")
                from collections import Counter
                word_counts = Counter(data)
                z = word_counts.most_common(1)
                for i, j in z:
                     print("最高票為",R2[i],"得到",j,"票")
                break     
            elif x == "C": 
                while True:
                    y=input("請輸入投票人數：")
                    if y.isdecimal()==False:
                        print("輸入錯誤！請重新輸入")
                    else:
                        break
                print("請從下列餐廳中選擇")
                for z in R3:
                    print(z,R3[z],)
                print("現在開始投票")
                count=int(y)
                data = []
                for item in range(count):
                    while True:
                            x = input("第"+str(item+1)+"位投票者請投票:")
                            if x == "A" or x == "B" or x == "C" or x == "D" or x == "E" or x == "F":
                                data.append(x)
                                break
                            else:
                                print("輸入錯誤！請重新輸入")
                else:print("投票完成")
                from collections import Counter
                word_counts = Counter(data)
                z = word_counts.most_common(1)
                for i, j in z:
                     print("最高票為",R3[i],"得到",j,"票")
                break       
            elif x == "D":
               
                while True:
                    y=input("請輸入投票人數：")
                    if y.isdecimal()==False:
                        print("輸入錯誤！請重新輸入")
                    else:
                        break
                print("請從下列餐廳中選擇")
                for z in R4:
                    print(z,R4[z],)
                print("現在開始投票")
                count = int(y)
                data = []
                for item in range(count):
                    while True:
                            x = input("第"+str(item+1)+"位投票者請投票:")
                            if x == "A" or x == "B" or x == "C" or x == "D" or x == "E" or x == "F" or x == "G" or x == "H" :
                                data.append(x)
                                break
                            else:
                                print("輸入錯誤！請重新輸入")
                else:print("投票完成")
                from collections import Counter
                word_counts = Counter(data)
                z = word_counts.most_common(1)
                for i, j in z:
                     print("最高票為",R4[i],"得到",j,"票")
                break
                        
            else:
                print("輸入錯誤！請重新輸入")
        
    elif x == "3":
        print("歡迎使用個人化選餐廳功能")
        import random

        R = []

        print('請輸入候選的餐廳，輸入完成請輸入0：')
        while  True:
            rest = str(input ('餐廳名稱：'))
            if R == [] and rest == '0':
                print("請先輸入餐廳")
            elif rest == '0':
                print("您的候選餐廳有：" + str(R)  )
                while True:
                    print("建議您吃" + random.choice(R))
                    x = input( "滿意這選擇嗎?(yes or no )")
                    if x == "yes":
                        break
                    elif x == "no":
                        continue
                break
            else:
                R.append(rest)

    elif x == "4":
        break
    else:
        print("請輸入正確代號,ex:1")

print("感謝使用，下次再見")
# Out:
# 歡迎使用吃飯小助手
# 請選擇功能:1.政大選餐廳,2.投票選餐廳,3.個人化選餐廳,4.結束1
# 歡迎使用政大選餐廳功能
# 要吃甚麼?請輸入地點代碼(大門=1/商側=2/麥側=3)1
# 要吃甚麼?請輸入種類(中式=1/日式=2/西式=3)3
# 舒曼
# 請問您是否滿意此結果?(滿意=1/不滿意=2)2
# 要吃甚麼?請輸入地點代碼(大門=1/商側=2/麥側=3)2
# 要吃甚麼?請輸入種類(中式=1/日式=2/西式=3)3
# urban monster
# 請問您是否滿意此結果?(滿意=1/不滿意=2)2
# 要吃甚麼?請輸入地點代碼(大門=1/商側=2/麥側=3)3
# 要吃甚麼?請輸入種類(中式=1/日式=2/西式=3)1
# 京華小館
# 請問您是否滿意此結果?(滿意=1/不滿意=2)1
# 請選擇功能:1.政大選餐廳,2.投票選餐廳,3.個人化選餐廳,4.結束4
# 感謝使用，下次再見
