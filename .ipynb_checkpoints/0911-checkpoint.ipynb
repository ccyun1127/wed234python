# %%
1+1
# Out:
# 2

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(1/2*np.pi)
# Out:
# 1.0

# %%
y = [3, -5,6, 7,-8, 9]

# %%
plt.plot(y)

# %%
x = [0, 0.7, np.sqrt(2), np.pi, 7, 7.9]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
x= np.linspace(-10, 10, 100)

# %%
len(x)
# Out:
# 100

# %%
y = np.sin(x)

# %%
len(y)
# Out:
# 100

# %%
plt.plot(x,y)

# %%
x = np.linspace(-100, 100, 100)

# %%
len(x)
# Out:
# 100

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
x = np.linspace(-100, 30, 30)
y = np.sin(x)

# %%
x2 = np.linspace(-100, 30, 30)
y2 = np.cos(x2)

# %%
plt.plot(x,y)
plt.plot(x2,y2)
